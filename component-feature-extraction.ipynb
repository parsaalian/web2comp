# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import time
import json
import uuid
import pickle
from dotenv import load_dotenv
from typing import List, Dict, Any, Optional, Tuple, Callable

import numpy as np
import pymongo

from web2comp.llm.gemini import (
    create_model,
    create_embedding_model
)
from web2comp.llm_processing import extract_response_from_tag

# %% [markdown]
# # Initialization

# %%
load_dotenv()
# Out:
# True

# %%
APP_NAME = 'DASHBOARD'

# %%
model = json.load(open(f'./new_models/{APP_NAME}.json'))

# %% [markdown]
# # Database Class

# %%
class InMemoryWarningVectorDB:
    def __init__(self):
        """
        Minimal in-memory database for storing features and component features,
        with vector similarity search capability.
        """
        self.features: Dict[str, Dict[str, Any]] = {}  # _id -> feature_doc
        self.component_features: List[Dict[str, Any]] = []
        
        self._all_feature_ids: List[str] = []
        self._all_embeddings_matrix: np.ndarray = np.array([], dtype=np.float32)
        self._embedding_dim: int = -1

    # --- Internal Embedding Management ---
    def _validate_and_set_embedding_dim(self, embedding: List[float]) -> None:
        current_len = len(embedding)
        if self._embedding_dim == -1:
            if current_len == 0:
                raise ValueError("Embedding dimension cannot be 0.")
            self._embedding_dim = current_len
            if self._all_embeddings_matrix.ndim == 1 and self._all_embeddings_matrix.shape[0] == 0:
                 self._all_embeddings_matrix = np.empty((0, self._embedding_dim), dtype=np.float32)
        elif current_len != self._embedding_dim:
            raise ValueError(
                f"All embeddings must have the same dimension. "
                f"Expected {self._embedding_dim}, got {current_len}."
            )

    def _rebuild_embeddings_index(self) -> None:
        if not self.features:
            self._all_feature_ids = []
            self._all_embeddings_matrix = np.empty((0, self._embedding_dim), dtype=np.float32) if self._embedding_dim != -1 else np.array([], dtype=np.float32)
            return

        temp_embeddings_list = []
        current_feature_ids = [] # Build locally then assign to self._all_feature_ids

        # Determine or validate embedding dimension if not already done or if features were empty before
        if self._embedding_dim == -1:
            for _id, feature_data in self.features.items():
                embedding = feature_data.get("embedding")
                if embedding is not None and isinstance(embedding, list) and len(embedding) > 0:
                    self._validate_and_set_embedding_dim(embedding) # This sets self._embedding_dim
                    break
        
        if self._embedding_dim == -1 and self.features: # Still no valid dimension found among features
            # Cannot build a meaningful matrix. This case implies features exist but none have valid embeddings.
            self._all_feature_ids = list(self.features.keys()) # Store IDs, but matrix will be empty or mis-shapen
            self._all_embeddings_matrix = np.array([], dtype=np.float32) # Or np.empty((0,0))
            # print("Warning: Features exist but no valid embeddings found to determine dimension. Index will be empty.")
            return


        for _id, feature_data in self.features.items():
            embedding = feature_data.get("embedding")
            if embedding is not None:
                if len(embedding) != self._embedding_dim: # Should have been caught by _validate_and_set_embedding_dim on add/update
                    raise ValueError(
                        f"Inconsistent embedding dimension for feature {_id}. "
                        f"Expected {self._embedding_dim}, got {len(embedding)}."
                    )
                temp_embeddings_list.append(embedding)
                current_feature_ids.append(_id)
        
        self._all_feature_ids = current_feature_ids
        if temp_embeddings_list:
            self._all_embeddings_matrix = np.array(temp_embeddings_list, dtype=np.float32)
        elif self._embedding_dim != -1: # No features with embeddings, but dim is known
            self._all_embeddings_matrix = np.empty((0, self._embedding_dim), dtype=np.float32)
        else: # No features with embeddings, dim unknown
            self._all_embeddings_matrix = np.array([], dtype=np.float32)


    def _cosine_similarity_matrix(self, query_vector: np.ndarray, target_matrix: np.ndarray) -> np.ndarray:
        if query_vector.ndim == 1:
            query_vector_2d = query_vector.reshape(1, -1)
        else:
            query_vector_2d = query_vector
        
        if target_matrix.shape[0] == 0:
            return np.array([])

        query_norm = np.linalg.norm(query_vector_2d, axis=1, keepdims=True)
        query_unit_vector = np.divide(query_vector_2d, query_norm, 
                                      out=np.zeros_like(query_vector_2d), where=query_norm!=0)

        target_norms = np.linalg.norm(target_matrix, axis=1, keepdims=True)
        target_unit_matrix = np.divide(target_matrix, target_norms, 
                                       out=np.zeros_like(target_matrix), where=target_norms!=0)
        
        similarities = np.dot(target_unit_matrix, query_unit_vector.T).flatten()
        return similarities

    # --- Feature Management Methods ---
    def add_feature(self, feature_doc: Dict[str, Any]) -> str:
        _id = str(feature_doc.get("_id", uuid.uuid4().hex)) # Use hex for shorter UUID string
        
        embedding_val = feature_doc.get("embedding")
        if embedding_val is None or not isinstance(embedding_val, list):
            raise ValueError("Feature document must contain a valid 'embedding' list.")
        
        self._validate_and_set_embedding_dim(embedding_val)
        
        feature_doc["_id"] = _id
        if _id in self.features:
            raise ValueError(f"Feature with ID {_id} already exists. Use update_feature instead.")
            
        self.features[_id] = feature_doc.copy() # Store a copy
        self._rebuild_embeddings_index()
        return _id

    def get_feature(self, feature_id: str) -> Optional[Dict[str, Any]]:
        feature = self.features.get(str(feature_id))
        return feature.copy() if feature else None # Return a copy

    def update_feature(self, feature_id: str, updates: Dict[str, Any]) -> bool:
        feature_id_str = str(feature_id)
        if feature_id_str not in self.features:
            return False
        
        original_feature = self.features[feature_id_str]
        embedding_changed = False
        modified = False

        if "embedding" in updates:
            new_embedding = updates["embedding"]
            if new_embedding is None or not isinstance(new_embedding, list):
                raise ValueError("Updated 'embedding' must be a valid list.")
            self._validate_and_set_embedding_dim(new_embedding)
            if original_feature.get("embedding") != new_embedding:
                embedding_changed = True
        
        for key, value in updates.items():
            if original_feature.get(key) != value:
                original_feature[key] = value
                modified = True
        
        if modified and embedding_changed:
            self._rebuild_embeddings_index()
        
        return modified

    def delete_feature(self, feature_id: str) -> bool:
        feature_id_str = str(feature_id)
        if feature_id_str in self.features:
            del self.features[feature_id_str]
            self._rebuild_embeddings_index()
            return True
        return False

    def list_features(self, app_filter: Optional[str] = None) -> List[Dict[str, Any]]:
        target_features = self.features.values()
        if app_filter:
            return [feat.copy() for feat in target_features if feat.get("app") == app_filter]
        return [feat.copy() for feat in target_features]

    def vector_search_features(self, query_embedding: List[float], top_k: int) -> List[Tuple[str, float]]:
        self._validate_and_set_embedding_dim(query_embedding)
        
        if self._all_embeddings_matrix.shape[0] == 0 or \
           (self._embedding_dim != -1 and self._all_embeddings_matrix.shape[1] != self._embedding_dim) :
            return []

        query_vec_np = np.array(query_embedding, dtype=np.float32)
        similarities = self._cosine_similarity_matrix(query_vec_np, self._all_embeddings_matrix)

        num_available_features = len(self._all_feature_ids)
        actual_top_k = min(top_k, num_available_features)

        if actual_top_k == 0 or similarities.size == 0:
            return []

        if actual_top_k < num_available_features:
            partitioned_indices = np.argpartition(similarities, -actual_top_k)[-actual_top_k:]
            candidate_indices = partitioned_indices[np.argsort(similarities[partitioned_indices])[::-1]]
        else:
            candidate_indices = np.argsort(similarities)[::-1]
            
        results = []
        for idx in candidate_indices:
            if idx < len(self._all_feature_ids):
                feature_id = self._all_feature_ids[idx]
                results.append((feature_id, float(similarities[idx])))
        return results

    # --- Component Feature Management Methods ---
    def add_component_feature(self, component_feature_doc: Dict[str, Any]) -> str:
        _id = str(component_feature_doc.get("_id", uuid.uuid4().hex))
        doc_copy = component_feature_doc.copy()
        doc_copy["_id"] = _id
        self.component_features.append(doc_copy)
        return _id

    def list_component_features(self, filters: Optional[Dict[str, Any]] = None) -> List[Dict[str, Any]]:
        if not self.component_features:
            return []
        
        source_list = self.component_features
        
        if not filters:
            return [doc.copy() for doc in source_list]
        
        results = []
        for doc in source_list:
            match = True
            for key, filter_value in filters.items():
                doc_value = doc.get(key)
                if isinstance(filter_value, dict) and '$in' in filter_value:
                    if doc_value not in filter_value['$in']:
                        match = False
                        break
                elif doc_value != filter_value:
                    match = False
                    break
            if match:
                results.append(doc.copy())
        return results

    def update_component_features(self, filter_criteria: Dict[str, Any], updates: Dict[str, Any]) -> int:
        updated_count = 0
        for doc in self.component_features: # Operates on original docs in list
            match = True
            for key, filter_value in filter_criteria.items():
                doc_value = doc.get(key)
                if isinstance(filter_value, dict) and '$in' in filter_value:
                    if doc_value not in filter_value['$in']:
                        match = False
                        break
                elif doc_value != filter_value:
                    match = False
                    break
            
            if match:
                for update_key, update_value in updates.items():
                    doc[update_key] = update_value
                updated_count += 1
        return updated_count

    def delete_component_features(self, filter_criteria: Dict[str, Any]) -> int:
        initial_count = len(self.component_features)
        new_list = []
        for doc in self.component_features:
            match = True
            for key, filter_value in filter_criteria.items():
                doc_value = doc.get(key)
                if isinstance(filter_value, dict) and '$in' in filter_value:
                    if doc_value not in filter_value['$in']:
                        match = False
                        break
                elif doc_value != filter_value:
                    match = False
                    break
            if not match:
                new_list.append(doc)
        
        deleted_count = initial_count - len(new_list)
        if deleted_count > 0:
            self.component_features = new_list
        return deleted_count

    # --- Utility ---
    def clear_all_data(self):
        self.features.clear()
        self.component_features.clear()
        self._all_feature_ids = []
        self._all_embeddings_matrix = np.array([], dtype=np.float32)
        self._embedding_dim = -1

# %%
def save_db_to_file(db_instance: InMemoryWarningVectorDB, filepath: str) -> None:
    """
    Saves the essential data of an InMemoryWarningVectorDB instance to a file using pickle.

    Args:
        db_instance: The instance of InMemoryWarningVectorDB to save.
        filepath: The path to the file where the data will be saved.

    Raises:
        Exception: Propagates exceptions that occur during file writing or pickling.

    Warning:
        The pickle module is not secure. Only use with trusted files.
    """
    data_to_save = {
        "features": db_instance.features,
        "component_features": db_instance.component_features,
        "_all_feature_ids": db_instance._all_feature_ids,
        "_all_embeddings_matrix": db_instance._all_embeddings_matrix,
        "_embedding_dim": db_instance._embedding_dim,
        # If you add other critical state attributes to your DB class,
        # make sure to include them here for persistence.
    }
    
    try:
        with open(filepath, 'wb') as f:
            pickle.dump(data_to_save, f, protocol=pickle.HIGHEST_PROTOCOL)
        print(f"Database state saved successfully to {filepath}")
    except Exception as e:
        print(f"Error saving database to {filepath}: {e}")
        raise # Re-raise the exception for the caller to handle

def load_db_from_file(filepath: str, db_class_constructor: type) -> Optional[InMemoryWarningVectorDB]:
    """
    Loads the data for an InMemoryWarningVectorDB from a file.

    Args:
        filepath: The path to the file from which to load the data.
        db_class_constructor: The constructor of your database class (e.g., InMemoryWarningVectorDB).
                              This is needed to create a new instance.

    Returns:
        A new instance of your database class populated with the loaded data,
        or None if loading fails.

    Warning:
        The pickle module is not secure. Only unpickle data from trusted sources.
    """
    try:
        with open(filepath, 'rb') as f:
            loaded_data = pickle.load(f)
            
        # Create a new instance using the provided constructor
        new_db_instance = db_class_constructor() 
        
        # Populate the instance with loaded data, with defaults for robustness
        new_db_instance.features = loaded_data.get("features", {})
        new_db_instance.component_features = loaded_data.get("component_features", [])
        new_db_instance._all_feature_ids = loaded_data.get("_all_feature_ids", [])
        
        loaded_matrix = loaded_data.get("_all_embeddings_matrix")
        if isinstance(loaded_matrix, np.ndarray):
            new_db_instance._all_embeddings_matrix = loaded_matrix
        elif loaded_matrix is not None: # Handle case if it was somehow saved not as ndarray
            print("Warning: Loaded embeddings matrix was not a NumPy ndarray. Attempting conversion.")
            new_db_instance._all_embeddings_matrix = np.array(loaded_matrix, dtype=np.float32)
        else: # Default to an empty array if missing or None
            new_db_instance._all_embeddings_matrix = np.array([], dtype=np.float32)

        new_db_instance._embedding_dim = loaded_data.get("_embedding_dim", -1)
        
        # Basic integrity check (optional, but can be helpful)
        if new_db_instance._embedding_dim != -1 and \
           new_db_instance._all_embeddings_matrix.ndim == 2 and \
           new_db_instance._all_embeddings_matrix.shape[0] > 0 and \
           new_db_instance._all_embeddings_matrix.shape[1] != new_db_instance._embedding_dim:
            print(f"Warning: Loaded embedding dimension ({new_db_instance._embedding_dim}) "
                  f"may be inconsistent with the loaded embeddings matrix shape "
                  f"({new_db_instance._all_embeddings_matrix.shape}). "
                  f"Consider data integrity or call _rebuild_embeddings_index() if issues arise.")
        
        # If the matrix is empty but an embedding dim is set, ensure it's 2D with correct second dim
        if new_db_instance._all_embeddings_matrix.shape[0] == 0 and \
           new_db_instance._embedding_dim != -1 and \
           (new_db_instance._all_embeddings_matrix.ndim != 2 or \
            (new_db_instance._all_embeddings_matrix.ndim == 2 and \
             new_db_instance._all_embeddings_matrix.shape[1] != new_db_instance._embedding_dim)):
            new_db_instance._all_embeddings_matrix = np.empty((0, new_db_instance._embedding_dim), dtype=np.float32)


        print(f"Database state loaded successfully from {filepath}")
        return new_db_instance
        
    except FileNotFoundError:
        print(f"Error: Database file not found at {filepath}")
        return None
    except pickle.UnpicklingError:
        print(f"Error: Could not unpickle data from {filepath}. "
              "File may be corrupted, not a pickle file, or from an incompatible version.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred while loading database from {filepath}: {e}")
        return None

# %% [markdown]
# # Inference Functions

# %% [markdown]
# ## Feature Extraction

# %%
FEATURE_EXTRACTION_PROMPT = """
You are an expert QA engineer. Your primary objective is to infer potential **User Operation Chains** that a given UI component (the `current component`) is likely to be part of. Each chain should correspond to a **single, specific user goal**.

A **User Operation** is defined as:
* **Entity Operations:** Actions corresponding to Create, Read, Update, or Delete (CRUD) operations on data entities (e.g., creating a new user, reading a product description, updating profile information, deleting an item from a cart). These actions should represent a committed change or retrieval of data.
* **Configuration Operations:** Actions that modify system configurations or user settings (e.g., toggling dark mode, adjusting notification preferences, signing in/out which changes an authentication flag). These actions should result in a persistent change to settings.

**Important Exclusions:**
1.  **Navigation:** Simple navigation actions, such as "Navigate to home page" or "Go to settings page," are **NOT** considered User Operations for this task unless they are an integral part of achieving a broader Entity or Configuration operation (e.g., navigating to a specific form to *then* create a new entity).
2.  **Cancellations/Dismissals:** Actions that primarily serve to cancel, abort, dismiss, or revert an ongoing process without a definitive data change or configuration commitment (e.g., "cancel form submission," "discard edits," "close modal without action") are **NOT** the target User Operations. Focus on operations that progress towards a completed goal.

You will infer these operation chains by analyzing the `current component` and, when available, the UI component interacted with in the immediately preceding state (the `previous component`).

## Input Information:
* **Current Webpage Context:** A description of the overall purpose or main function of the current webpage.
* **Current Component's Hierarchical Context:** Descriptions of all ancestor elements of the `current component`, providing its placement within the UI structure.
* **Current Component's Context:** A specific description detailing the `current component` being analyzed.
* **Current Component's Code:** The React code snippet for the `current component`.
* **(Optional) Previous Component's Full Context:** If provided, this includes the Hierarchical Context, Context, and Code for the component interacted with in the *previous UI state*.

## Your Goal:
Analyze the provided information for the `current component` (and `previous component`, if available). Your primary goal is to identify and describe potential **User Operation Chains**. Each User Operation Chain represents a sequence of operations a user might perform to achieve **one specific, distinct overall user goal**.

For example, if a component is a "Manage Items" button leading to a page where items can be viewed, created, or deleted:
* A potential goal is "View list of items." Chain: `Read (Item List)`
* Another distinct goal is "Create a new item." Chain: `Create (New Item)`
* Another distinct goal is "Delete an existing item." Chain: `Delete (Specific Item)`

The User Operations you predict do not need to occur *immediately* after interacting with the given components, but the components should clearly indicate the possibility of these operations forming part of a user's workflow towards a specific, constructive outcome.

**Focus:** You are predicting the sequence of underlying system operations (Entity or Configuration) and the **single, specific, user-centric purpose** that the `current component` (potentially in sequence with the `previous component`) helps achieve. Formulate a concise, natural language label for this **overall user goal**.
* **Granularity:** Each predicted goal must be singular. Avoid bundling multiple distinct operations (e.g., do not use "Manage X (view, edit, delete)"). Instead, if the component(s) suggest multiple distinct goals like "View X," "Edit X," and "Delete X," identify each as a separate potential User Goal with its own chain and likelihood.
* **Exclusions:** Avoid identifying goals that are solely navigational or represent a cancellation/dismissal of an action. The goal should reflect a meaningful, progressive interaction with data or system settings, leading to a committed state.

## Prediction Categorization by Likelihood:
Categorize each inferred User Operation Chain (and its single, specific User Goal) based on its probability of existence:
* **Category 1: Extremely Probable:** Given the component(s) and context, this specific User Goal and its chain (leading to a constructive outcome) are almost certainly supported.
* **Category 2: Probable:** The specific User Goal and its chain (leading to a constructive outcome) are plausible, but existence isn't guaranteed without further observation or broader application context.
* **Category 3: Extremely Improbable:** It's highly unlikely this specific constructive User Goal and its chain are relevant to the given component(s), though a remote theoretical possibility might exist.

Generate as many distinct User Operation Chains (and their corresponding single User Goals) as the provided information reasonably implies, keeping the exclusion and granularity criteria in mind. Categories can be empty.

## Output Format:

Your response must be structured into two distinct sections, enclosed in the specified tags:

<Reasoning>
Provide a concise, step-by-step thought process for your inferences.
-   For each potential **single, specific User Goal** (and its implied operation chain) you considered:
    1.  **User Goal:** State the overall user goal (e.g., "View product reviews," "Create a new user profile," "Delete an item from cart"). Ensure this is a single, specific goal and not a bundled set of operations, a simple navigation task, or a cancellation/dismissal.
    2.  **Implied Operation Chain:** Outline the sequence of User Operations (e.g., `Read (Product Details) -> Read (Product Reviews)` or `Create (UserProfile)`). Clearly specify the Entity Operation (CRUD on which entity?) or Configuration Operation. Ensure operations are constructive and not merely abortive.
    3.  **Role of Current Component:** Explain which specific User Operation in this chain the `current component` directly facilitates towards achieving this single goal.
    4.  **Role of Previous Component (if provided and relevant):** If the `previous component`'s context was available and used in your inference, describe how its facilitated User Operation leads to or sets up the `current component`'s operation within this chain for this specific goal. Explain how analyzing both components *together* strengthens the prediction of this chain and goal. If not relevant or not provided, state so.
    5.  **Likelihood & Justification:** Assign a likelihood (Extremely Probable, Probable, Extremely Improbable) to this specific User Goal and its chain. Justify your categorization based on the provided component(s), their context, and common user interaction patterns, focusing on constructive outcomes.
-   Avoid re-stating the questions from this prompt in your reasoning. Provide direct answers.

</Reasoning>

<Response>
This section must contain a single JSON array of objects, parsable by `json.loads` in Python. Do not include any explanatory text or formatting outside this JSON structure.
-   Each object in the array represents **one** inferred User Goal and its associated chain.
-   Each object must contain two keys:
    * `"category"`: An integer (`1`, `2`, or `3`) corresponding to the likelihood categories (1: Extremely Probable, 2: Probable, 3: Extremely Improbable).
    * `"feature"`: A concise natural language label describing the **single, specific overall user goal** (e.g., "Add item to shopping cart," "Update notification preferences," "View order history," "Create new pet entry," "Edit pet details," "Delete specific pet"). This label should *not* describe a purely navigational task, a cancellation/dismissal of a process, or a bundled set of multiple operations (e.g., avoid "Manage pets").
-   The JSON array should be sorted by `"category"` in ascending order.
</Response>

Example for <Response>:
```json
[
  {
    "category": 1,
    "feature": "Search for products"
  },
  {
    "category": 1,
    "feature": "View product details after search"
  },
  {
    "category": 2,
    "feature": "Add searched product to wishlist"
  },
  {
    "category": 2,
    "feature": "Create a new pet profile"
  },
  {
    "category": 2,
    "feature": "Edit an existing pet profile"
  }
]
```
""".strip()


feature_extraction_model = create_model(FEATURE_EXTRACTION_PROMPT)


def extract_component_features(state, component, prev_component=None):
    prompt=f'Page Context: {state['context']}\nHierarchical Context:\n{component['hcontexts']}\nComponent Context: {component['context']}\nComponent Code:\n{component['code']}'
    if prev_component is not None:
        prompt += f'Prev Hierarchical Context:\n{prev_component['hcontexts']}\n'
        prompt += f'Prev Component Context: {prev_component['context']}\n'
        prompt += f'Prev Component Code: {prev_component['code']}'
    
    res = feature_extraction_model(
        prompt=prompt
    ).text

    try:
        features = json.loads(extract_response_from_tag(res, 'Response'))
    except:
        print(res)

    return features

# %% [markdown]
# ## Feature to Database

# %%
def category_to_score(category):
    p_map = {
        1: 0.9,
        2: 0.5,
        3: 0.1,
        4: 0.01
    }

    return np.log(p_map[category])

# %%
def query_similar_features(
    db: InMemoryWarningVectorDB,
    app_name: str,
    query_embedding: List[float],
    vector_search_limit: int = 10, 
    result_limit: int = 5
) -> List[Dict[str, Any]]:
    candidate_tuples = db.vector_search_features(query_embedding, top_k=vector_search_limit) 

    results = []
    for feature_id, similarity_score in candidate_tuples:
        feature_doc = db.get_feature(feature_id) # Returns a copy
        if feature_doc and feature_doc.get("app") == app_name:
            feature_doc['search_similarity_score'] = similarity_score 
            results.append(feature_doc)
            if len(results) >= result_limit:
                break
    return results

# %%
def get_exact_match_indices(text, similar_features):
    indices = []
    
    for i in range(len(similar_features)):
        if similar_features[i]['text'] == text:
            indices.append(i)
    
    return indices


SIMILARITY_PROMPT = """
Given a description of a software feature and a list of other software feature descriptions, your task is to determine if the initial feature matches any features in the list.

Output format:
Your analysis is enclosed in two tags:
<Reasoning>
- For each item in the list, argue why the base feature and the feature in the list are or aren't describing the same action being performed in the app.
    - Are they exactly or semantically equivalent?
    - If they are different, how are they different?
- Avoid repeating the questions in your responses every time.
- Your analyses should be short and concise.
</Reasoning>
<Response>
- A JSON object containing the following keys:
    - match: true If any feature in the list matches the base feature, false if not.
    - match_index: An array of indices of matched features in the list. Only include this key if there is a matching feature.
    - combined_text: If the features match, a concise description of that feature. Only include this key if there is a matching feature. You can omit some of the redundant words to keep this sentence simple.
- Parsable by `json.loads`.
</Response>
""".strip()


similarity_model = create_model(SIMILARITY_PROMPT)


def map_similar_feature_to_exact_match(feature_info):
    category, text, embedding, similar_features = feature_info

    # print('\n'.join(map(lambda x: f'{str(x['_id'])}, {x['text']}', similar_features)))
    
    exact_match_indices = get_exact_match_indices(text, similar_features)
    
    if len(exact_match_indices) > 0:
        match = {
            'match': True,
            'match_index': exact_match_indices,
            'combined_text': text
        }
    else:
        match = {
            'match': False
        }
    
    if len(similar_features) != 0:
        res = similarity_model(
            prompt=f'Base feature:\n{text}\nThe list of features:\n{'\n'.join(map(lambda x: x['text'], similar_features))}'
        ).text.replace('```json', '').replace('```', '')
        # print(res)
        
        match = json.loads(extract_response_from_tag(res, 'Response'))
        
        if 'match_index' in match:
            match['match_index'] = list(set(match['match_index'] + exact_match_indices))
        elif len(exact_match_indices) > 0:
            match['match_index'] = exact_match_indices
            match['combined_text'] = text
    
    if match['match']:
        if type(match['match_index']) == int:
            match['match_id'] = [similar_features[match['match_index']]['_id']]
        else:
            match['match_id'] = [similar_features[m]['_id'] for m in match['match_index']]
    
    match['category'] = category
    match['text'] = text
    match['embedding'] = embedding
    
    return match

# %%
google_embedding = create_embedding_model()

# %%
def no_match_insert(
    db: InMemoryWarningVectorDB, 
    app_name: str,
    text: str,
    embedding: List[float], # Assumed to be pre-calculated
    score: float,         # Assumed to be pre-calculated
    final: bool = False
) -> str:
    feature_doc = {
        "app": APP_NAME,
        "text": text,
        "embedding": embedding,
        "score": score,
        "final": False
        # _id will be auto-generated by db.add_feature if not provided
    }
    inserted_id = db.add_feature(feature_doc)
    return inserted_id


def match_update(
    db: InMemoryWarningVectorDB,
    app_name: str,
    match_ids: List[str], # List of feature IDs, first is primary
    combined_text: str,
    new_embedding: List[float] # Assumed to be pre-calculated
) -> Optional[str]:

    if not match_ids:
        return None # No IDs provided
        
    primary_match_id = str(match_ids[0])
    
    primary_feature = db.get_feature(primary_match_id)
    if not primary_feature or primary_feature.get("app") != app_name:
        return None # Primary feature doesn't exist or not for this app

    # Update the primary feature
    update_payload = {
        "text": combined_text,
        "embedding": new_embedding
        # Note: 'app' is not changed, _id is the key
    }
    db.update_feature(primary_match_id, update_payload)

    ids_to_process_for_deletion = [str(mid) for mid in match_ids[1:]]
    successfully_deleted_ids_for_comp_feat_update = []

    if ids_to_process_for_deletion:
        for id_to_delete in ids_to_process_for_deletion:
            if id_to_delete == primary_match_id: # Should not happen with match_ids[1:]
                continue
            feature_to_delete = db.get_feature(id_to_delete)
            if feature_to_delete and feature_to_delete.get("app") == app_name:
                if db.delete_feature(id_to_delete):
                    successfully_deleted_ids_for_comp_feat_update.append(id_to_delete)
        
        if successfully_deleted_ids_for_comp_feat_update:
            comp_feat_filter = {
                "app": app_name,
                "feature_pointer": {"$in": successfully_deleted_ids_for_comp_feat_update}
            }
            comp_feat_update_payload = {"feature_pointer": primary_match_id}
            db.update_component_features(comp_feat_filter, comp_feat_update_payload)
            
    return primary_match_id


def update_databases_with_match(
    db: InMemoryWarningVectorDB,
    app_name: str,
    match: Dict[str, Any]
):
    if match['match']:
        return match_update(
            db=db,
            app_name=app_name,
            match_ids=match['match_id'],
            combined_text=match['combined_text'],
            new_embedding=google_embedding(match['combined_text'])
        )
    return no_match_insert(
        db=db,
        app_name=app_name,
        text=match['text'],
        embedding=match['embedding'],
        score=category_to_score(match['category']),
        final=False
    )

# %%
def insert_features(
    db: InMemoryWarningVectorDB,
    app_name: str,
    features: List[Dict]
) -> List[str]:
    feature_categories = list(map(lambda x: x['category'], features))
    feature_descriptions = list(map(lambda x: x['feature'], features))
    feature_embeddings = google_embedding(feature_descriptions, default_as_list=True)

    similar_features = map(
        lambda x: query_similar_features(db=db, app_name=app_name, query_embedding=x),
        feature_embeddings
    )

    matches = map(
        map_similar_feature_to_exact_match,
        zip(
            feature_categories,
            feature_descriptions,
            feature_embeddings,
            similar_features
        )
    )

    insertion_ids = list(map(
        lambda x: update_databases_with_match(db=db, app_name=app_name, match=x),
        matches
    ))
    
    return insertion_ids

# %%
def insert_action_features(
    db: InMemoryWarningVectorDB,
    # Common data for all documents in this batch
    app_name: str, 
    state_url: str,
    state_id: str,
    prev_state_id: str,
    component_id: str,
    prev_component_id: str,
    component_depth: int,
    component_type: str,
    # Each tuple: (dict_with_category_info, feature_id_to_point_to)
    per_item_data: List[Tuple[Dict[str, Any], str]], 
) -> List[str]:

    inserted_comp_feature_ids = []
    for item_specifics, feature_pointer_val in per_item_data:
        document = {
            "app": app_name,
            "url": state_url,
            "state": state_id,
            "prev_state": prev_state_id,
            "component": component_id,
            "prev_component": prev_component_id,
            "depth": component_depth,
            "type": component_type,
            "rank_score": category_to_score(item_specifics['category']),
            "feature_pointer": str(feature_pointer_val),
            "final": False, # Default as in original user code
            # _id will be auto-generated by db.add_component_feature
        }
        inserted_id = db.add_component_feature(document)
        inserted_comp_feature_ids.append(inserted_id)
        
    return inserted_comp_feature_ids

# %% [markdown]
# ## Mark Features

# %%
def update_feature_score(
    db: InMemoryWarningVectorDB,
    app_name: str,
    prev_state: Dict[str, Any],
    prev_comp: Dict[str, Any],
    curr_state: Dict[str, Any],
    curr_comp: Dict[str, Any]
) -> None:
    # Fetch current action's "DOUBLE" type component features
    curr_comp_features = db.list_component_features(filters={
        'app': app_name,
        'state': curr_state['id'],
        'component': curr_comp['id'],
        'type': 'DOUBLE'
    })
    
    # Fetch previous action's "SINGLE" type component features
    prev_comp_features = db.list_component_features(filters={
        'app': app_name,
        'state': prev_state['id'],
        'component': prev_comp['id'],
        'type': 'SINGLE'
    })
    
    feature_score_updates: Dict[str, float] = {} # feature_pointer_id -> score_difference
    
    for curr_comp_feat in curr_comp_features:
        feature_pointer = curr_comp_feat.get('feature_pointer')
        if not feature_pointer:
            continue
            
        corresponding_prev_comp_feat = list(filter(
            lambda x: x.get('feature_pointer') == feature_pointer, 
            prev_comp_features
        ))
        
        prev_score = category_to_score(4) # Default if no corresponding previous
        if corresponding_prev_comp_feat:
            prev_score = corresponding_prev_comp_feat[0].get('rank_score', 0.0)
            
        current_rank_score = curr_comp_feat.get('rank_score', 0.0)
        diff = current_rank_score - prev_score
        feature_score_updates[str(feature_pointer)] = diff # Ensure feature_pointer is string
    
    for feature_id_str, score_diff in feature_score_updates.items():
        feature_to_update = db.get_feature(feature_id_str) # get_feature returns a copy
        
        if feature_to_update and \
           feature_to_update.get('app') == app_name and \
           not feature_to_update.get('final', False): # Check 'final' status
            
            current_score = feature_to_update.get('score', 0.0)
            new_score = current_score + score_diff
            db.update_feature(feature_id_str, {'score': new_score})

# %%
FINALITY_PROMPT = """
You are an expert QA engineer. Your task is to analyze a given UI component (the `current component`) and determine if interacting with it represents the **final step** taken by the user before a specific **User Operation Goal** is achieved. A User Operation Goal refers to the successful completion of an Entity Operation or a Configuration Operation.

**Key Definitions:**
* **User Operation Goal:** The user's aim to complete an Entity Operation or Configuration Operation.
    * **Entity Operations:** Actions corresponding to Create, Read, Update, or Delete (CRUD) operations on data entities (e.g., submitting a form to create an account, saving changes to a profile, confirming a deletion).
    * **Configuration Operations:** Actions that modify system configurations or user settings (e.g., applying a new theme, saving notification preferences).
* **Final Step:** Interacting with the `current component` is the last action a user needs to perform on the UI to trigger the backend processing of the User Operation or to see the User Operation Goal realized. No further UI interactions are required for that specific goal after this component.

## Input Information:
* **Current Webpage Context:** Description of the purpose of the current webpage.
* **Current Component's Hierarchical Context:** Contextual descriptions for all ancestor elements of the `current component`.
* **Current Component's Context:** A specific description of the `current component` being analyzed.
* **Current Component's Code:** The React code snippet for the `current component`.
* **Target User Operation Goals:** A list of specific User Operation Goals (e.g., "Submit user registration form," "Save notification settings," "View account summary"). You will evaluate the `current component` against each goal in this list.

## Your Task:
For each User Operation Goal provided in the **Target User Operation Goals** list, determine if interacting with the `current component` is the **final step** that immediately leads to the achievement of that goal.

## Output Format:

Your analysis must be enclosed in two distinct tags:

<Reasoning>
Detail your thought process concisely for each User Operation Goal from the input list.
-   For each User Operation Goal:
    1.  Clearly state the User Operation Goal you are evaluating (you can refer to it by its description or index).
    2.  Argue whether interacting with the `current component` would or would not conclude the actions required for this specific User Operation Goal.
    3.  Consider if any further component interactions by the user are necessary after the `current component` to achieve this goal.
    4.  If the `current component` is *not* final for the goal, briefly state why (e.g., "requires subsequent 'Confirm' button click," "only updates a field, needs form submission").
-   Avoid repeating the full description of the User Operation Goal if referencing by name/index is clear.
-   Your analyses should be short and concise.
</Reasoning>

<Response>
This section must contain a single JSON array of boolean values.
-   The array must directly correspond to the order of the **Target User Operation Goals** provided in the input.
-   The boolean value at index `i` in the array should be `true` if interacting with the `current component` is the final step to achieve the User Operation Goal `i` from the input list. Otherwise, the value should be `false`.
-   The output must be parsable by `json.loads` in Python (use `true` and `false` for boolean values). Do not include any explanatory text outside the JSON array in this section.
</Response>
""".strip()


finality_model = create_model(FINALITY_PROMPT)


def mark_final_features(
    db: InMemoryWarningVectorDB,
    app_name: str,
    curr_state: Dict[str, Any],
    curr_comp: Dict[str, Any]
) -> None:
    # Fetch component features related to the current state and action
    current_comp_features = db.list_component_features(filters={
        'app': app_name,
        'state': curr_state['id'],
        'component': curr_comp['id'],
    })

    if not current_comp_features:
        return

    # Collect unique function pointers (which are feature IDs)
    func_pointer_ids = list(set(
        str(cf['func_pointer']) for cf in current_comp_features if 'func_pointer' in cf
    ))

    if not func_pointer_ids:
        return

    # Retrieve the actual feature documents ("functionalities")
    retrieved_features: List[Dict[str, Any]] = []
    for fp_id in func_pointer_ids:
        feature = db.get_feature(fp_id) # Returns a copy
        if feature and feature.get('app') == app_name:
            retrieved_features.append(feature)
            
    if not retrieved_features:
        return
    
    # Prepare data for and call the LLM
    # Assuming curr_state['context'] and curr_comp['outerHTML'] exist
    # And feature documents have a 'text' field
    llm_response = finality_model(
        prompt=f'App Context: {state['context']}\nHierarchical\'s Context:\n{'\n'.join(curr_comp['hcontexts'])}\nComponent Context: {curr_comp['context']}\nComponent Code: {curr_comp['code']}\nFeatures:\n{'\n'.join(feat.get('text', '') for feat in retrieved_features)}'
    ).text

    try:
        # The original code uses eval, which can be risky.
        # Ensure the LLM output is strictly controlled or use a safer parsing method.
        finality_list_str = extract_response_from_tag(llm_response, 'Response')
        finality_determinations = eval(finality_list_str) # Example: [True, False, True, ...]
        
        if not isinstance(finality_determinations, list) or \
           len(finality_determinations) != len(retrieved_features):
            print(f"Warning: Mismatch between finality determinations ({len(finality_determinations)}) and "
                  f"retrieved features ({len(retrieved_features)}). Or invalid format.")
            return

    except Exception as e:
        print(f"Error processing LLM response for finality: {e}")
        return

    for i, is_final in enumerate(finality_determinations):
        if is_final:
            feature_to_mark = retrieved_features[i]
            feature_id_to_mark = str(feature_to_mark['_id'])

            # Mark the feature itself as final
            db.update_feature(feature_id_to_mark, {'final': True})
            
            # Mark related component_features as final
            # This targets only those component_features that were initially fetched and led to this feature.
            # The original query was specific to `curr_comp['id']` and `curr_state['id']`
            filter_for_comp_features = {
                'app': app_name,
                'func_pointer': feature_id_to_mark,
                'component': curr_comp['id'],
                'state': curr_state['id']
            }
            db.update_component_features(
                filter_criteria=filter_for_comp_features,
                updates={'final': True}
            )

# %% [markdown]
# # Feature Extraction Loop

# %%
in_memory_db = InMemoryWarningVectorDB()

# %%
queue = [
    list(model['nodes'].keys())[0]
]

# %%
queue
# Out:
# ['3a9a0cc95faadb210453ae06e176340513c3b2fd4ac65ae6d0f81afdae9340dc']

# %%
while len(queue) > 0:
    state_id = queue[0]
    print(f"Visiting state {state_id}")

    state = model['nodes'][state_id]

    for component in state['components']:
        print(f'Extracting component scenarios: {component['id']}')
        
        if component['original_state'] != '' and component['original_state'] != state_id:
            continue

        prev_state = model['nodes'][state['prev_state']] if state['depth'] > 0 else None
        prev_action = state['prev_action']
        try:
            prev_component = list(filter(
                lambda c: prev_action['id'].replace('//BODY', '//html[1]/body[1]').lower() in list(map(lambda a: a['id'], c['actions'])),
                prev_state['components']
            ))[0] if state['depth'] > 0 else None
        except:
            prev_component = None

        
        features = extract_component_features(state, component)
        print(features)

        if len(features) != 0:
            feature_ids = insert_features(db=in_memory_db, app_name=APP_NAME, features=features)
            insert_action_features(
                db=in_memory_db,
                app_name=APP_NAME,
                state_url=state['url'],
                state_id=state_id,
                prev_state_id=state['prev_state'],
                component_id=component['id'],
                prev_component_id=prev_component['id'] if prev_component is not None else None,
                component_depth=state['depth'],
                component_type="SINGLE",
                per_item_data=list(zip(features, feature_ids))
            )
        
        if state['depth'] > 0 and prev_component is not None:
            print('Extracting double action scenarios')

            double_features = extract_component_features(state, component, prev_component)
            print(double_features)

            if len(double_features) != 0:
                double_feature_ids = insert_features(db=in_memory_db, app_name=APP_NAME, features=double_features)
                insert_action_features(
                    db=in_memory_db,
                    app_name=APP_NAME,
                    state_url=state['url'],
                    state_id=state_id,
                    prev_state_id=state['prev_state'],
                    component_id=component['id'],
                    prev_component_id=prev_component['id'],
                    component_depth=state['depth'],
                    component_type="DOUBLE",
                    per_item_data=list(zip(double_features, double_feature_ids))
                )
            
            print('Updating action scores')

            update_feature_score(
                db=in_memory_db,
                app_name=APP_NAME,
                prev_state={ 'id': state['prev_state'], **prev_state },
                prev_comp=prev_component,
                curr_state={ 'id': state_id, **state },
                curr_comp=component
            )

            print('Action scores updated')

        print('Marking final functionalities')

        mark_final_features(
            db=in_memory_db,
            app_name=APP_NAME,
            curr_state={ 'id': state_id, **state },
            curr_comp=component
        )
    
        print('Final actions marked')
    
    if state_id in model['edges']:
        for target_state in model['edges'][state_id].values():
            queue.append(target_state)
    
    queue = queue[1:]
# Out:
# Visiting state 3a9a0cc95faadb210453ae06e176340513c3b2fd4ac65ae6d0f81afdae9340dc
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Log into the application'}, {'category': 1, 'feature': 'Reset user password'}]
# Marking final functionalities
# Final actions marked
# Visiting state f3da9e519a1a495ba0b9e0d8501cc460495b087624abd9f91180ebf647b3126b
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# [{'category': 1, 'feature': 'Read store configuration details (including avatar)'}, {'category': 2, 'feature': 'Update store avatar image'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# [{'category': 1, 'feature': 'View product details'}, {'category': 1, 'feature': 'View order details'}, {'category': 1, 'feature': 'View customer details'}, {'category': 1, 'feature': 'View discount details'}, {'category': 1, 'feature': 'View content pages'}, {'category': 1, 'feature': 'View translations'}, {'category': 1, 'feature': 'View installed apps'}, {'category': 1, 'feature': 'View configuration settings'}, {'category': 2, 'feature': 'Create a new product'}, {'category': 2, 'feature': 'Create a new order'}, {'category': 2, 'feature': 'Create a new discount'}, {'category': 2, 'feature': 'Update configuration settings'}, {'category': 2, 'feature': 'Create a new customer'}, {'category': 2, 'feature': 'Create new content page'}, {'category': 2, 'feature': 'Create new translation'}, {'category': 2, 'feature': 'Install a new app'}, {'category': 2, 'feature': 'Edit product details'}, {'category': 2, 'feature': 'Edit order details'}, {'category': 2, 'feature': 'Edit customer details'}, {'category': 2, 'feature': 'Edit discount details'}, {'category': 2, 'feature': 'Edit content page'}, {'category': 2, 'feature': 'Edit translation'}, {'category': 2, 'feature': 'Uninstall an app'}, {'category': 2, 'feature': 'Delete a product'}, {'category': 2, 'feature': 'Delete an order'}, {'category': 2, 'feature': 'Delete a customer'}, {'category': 2, 'feature': 'Delete a discount'}, {'category': 2, 'feature': 'Delete a content page'}, {'category': 2, 'feature': 'Delete a translation'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View overall dashboard information'}, {'category': 1, 'feature': 'View dashboard information filtered by channel'}, {'category': 2, 'feature': 'Update the default channel setting'}, {'category': 3, 'feature': 'Create a new channel'}, {'category': 3, 'feature': 'Delete an existing channel'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[3]
# [{'category': 1, 'feature': 'View recent store activity'}, {'category': 2, 'feature': 'Be notified of new store activity'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[4]
# [{'category': 1, 'feature': 'View top products list'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'View daily sales total'}, {'category': 2, 'feature': 'View sales total for a different time period'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[2]/div[2]
# [{'category': 1, 'feature': 'View the number of items currently out of stock'}, {'category': 2, 'feature': 'View a list of items that are out of stock'}, {'category': 2, 'feature': 'Update the stock levels of items'}]
# Marking final functionalities
# Final actions marked
# Visiting state ee81ed1f1d52ac339073c34c02eee05f139eb8d03ca59609234f1cbc385a5044
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Create a new product'}, {'category': 1, 'feature': 'View product list'}, {'category': 2, 'feature': 'Access product settings'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# []
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# [{'category': 1, 'feature': 'View list of orders'}, {'category': 2, 'feature': 'Search for a specific order'}, {'category': 2, 'feature': 'View details of a specific order'}, {'category': 2, 'feature': 'Update an existing order'}, {'category': 2, 'feature': 'Delete an order'}, {'category': 3, 'feature': 'Create a new order'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# [{'category': 1, 'feature': 'View list of customers'}, {'category': 2, 'feature': 'Create a new customer'}, {'category': 2, 'feature': 'Edit an existing customer'}, {'category': 2, 'feature': 'Delete an existing customer'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# [{'category': 1, 'feature': 'View available discounts'}, {'category': 2, 'feature': 'Apply a discount'}, {'category': 2, 'feature': 'Create a new discount'}, {'category': 2, 'feature': 'Edit an existing discount'}, {'category': 2, 'feature': 'Delete an existing discount'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# [{'category': 1, 'feature': 'View content management section'}, {'category': 2, 'feature': 'Create new content'}, {'category': 2, 'feature': 'Update existing content'}, {'category': 2, 'feature': 'Delete existing content'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# [{'category': 1, 'feature': 'View list of translations'}, {'category': 2, 'feature': 'Create a new translation'}, {'category': 2, 'feature': 'Update an existing translation'}, {'category': 2, 'feature': 'Delete an existing translation'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# [{'category': 1, 'feature': 'View list of applications'}, {'category': 2, 'feature': 'View specific application details'}, {'category': 2, 'feature': 'Update specific application configuration'}, {'category': 2, 'feature': 'Create a new application'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# [{'category': 1, 'feature': 'Read system configuration settings'}, {'category': 1, 'feature': 'Update system configuration settings'}, {'category': 2, 'feature': 'Create a new configuration setting'}, {'category': 2, 'feature': 'Delete a configuration setting'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]/div[1]/li[1]
# [{'category': 1, 'feature': 'View list of products'}, {'category': 2, 'feature': 'Create a new product'}, {'category': 2, 'feature': 'Manage product categories'}, {'category': 2, 'feature': 'Manage product collections'}, {'category': 2, 'feature': 'Manage gift cards'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View product categories'}, {'category': 1, 'feature': 'View product collections'}, {'category': 1, 'feature': 'View gift cards'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[1]/div[2]
# [{'category': 1, 'feature': 'Change product list display format'}, {'category': 1, 'feature': 'View product list in preferred format'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[2]/div[2]
# [{'category': 1, 'feature': 'Read product list with pagination controls'}, {'category': 1, 'feature': 'Navigate to the next page of the product list'}, {'category': 1, 'feature': 'Navigate to the previous page of the product list'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[1]/div[1]/button[1]
# [{'category': 1, 'feature': 'Apply filters to the product list'}, {'category': 1, 'feature': 'View the product list based on applied filters'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Search for products'}, {'category': 2, 'feature': 'View product details after searching'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[1]/div[3]
# [{'category': 1, 'feature': 'Edit specific product details'}, {'category': 1, 'feature': 'Configure columns displayed in the product table'}, {'category': 2, 'feature': 'View detailed information for a specific product'}, {'category': 2, 'feature': 'Delete a specific product'}, {'category': 2, 'feature': 'Duplicate a specific product'}, {'category': 3, 'feature': 'Create a new product'}]
# Marking final functionalities
# Final actions marked
# Visiting state 207c1499d784cc77cca9e0c4d58bf200a14f8a2d90ee08ca3d2e1b18f1d16964
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View list of sales orders'}, {'category': 2, 'feature': 'Create a new sales order'}, {'category': 2, 'feature': 'Update the status of an existing sales order'}, {'category': 2, 'feature': 'Delete an existing sales order'}, {'category': 2, 'feature': 'Configure order settings'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'Filter the list of orders'}, {'category': 1, 'feature': 'Search the list of orders'}, {'category': 2, 'feature': 'View details of a specific order after filtering/searching'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]/div[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]/div[1]/div[1]
# [{'category': 1, 'feature': 'View list of draft orders'}, {'category': 2, 'feature': 'Create a new draft order'}, {'category': 2, 'feature': 'Edit an existing draft order'}, {'category': 2, 'feature': 'Delete an existing draft order'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[2]/div[2]
# Visiting state f0489e1b40870068303f24a4200d7336ab9d448b0e44664834d6caf6bb0a83db
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# [{'category': 1, 'feature': 'View list of customers'}, {'category': 2, 'feature': 'Create a new customer entry'}, {'category': 2, 'feature': 'Edit an existing customer entry'}, {'category': 2, 'feature': 'Delete an existing customer entry'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[3]
# [{'category': 1, 'feature': 'View different pages of the customer list'}, {'category': 1, 'feature': 'Configure the number of customers displayed per page'}]
# Marking final functionalities
# Final actions marked
# Visiting state ad044d0bc350c8f2363ef43c008d538f1d644c1becb01abf3e45ecc763b028a5
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# [{'category': 1, 'feature': 'View list of discounts'}, {'category': 1, 'feature': 'View list of vouchers'}, {'category': 2, 'feature': 'Create a new discount'}, {'category': 2, 'feature': 'Create a new voucher'}, {'category': 2, 'feature': 'Update an existing discount'}, {'category': 2, 'feature': 'Update an existing voucher'}, {'category': 2, 'feature': 'Delete an existing discount'}, {'category': 2, 'feature': 'Delete an existing voucher'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'Filter the list of discounts'}, {'category': 1, 'feature': 'Search the list of discounts'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[3]
# Visiting state a2ab55fe13c17d343eb88ebed421ae14e7e7ccab473b8077ac3750f92e595fc6
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Create new content'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'Filter content list'}, {'category': 1, 'feature': 'Search content list'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[3]
# Visiting state 991130387ee0b2ace07eb384abe51a89112a3aaef267b692e6386f520905185e
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]
# [{'category': 1, 'feature': 'View translations for a specific language'}, {'category': 2, 'feature': 'Update translations for a specific language'}, {'category': 2, 'feature': 'Delete translations for a specific language'}, {'category': 2, 'feature': 'Create new translations for a specific language'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Visiting state 0984ad04d2a6115d1d780f52fcaf140bf3a5e5d75e972e4389047601826f0255
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]
# [{'category': 1, 'feature': 'Install a new external application'}, {'category': 1, 'feature': 'View the list of available applications'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[1]/div[1]
# [{'category': 1, 'feature': 'View list of installed applications'}, {'category': 2, 'feature': 'Uninstall an installed application'}, {'category': 2, 'feature': 'Update configuration for an installed application'}, {'category': 3, 'feature': 'Install a new application'}, {'category': 3, 'feature': 'View details of an available application'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[1]/div[3]/h3[1]
# [{'category': 1, 'feature': 'View list of available applications'}, {'category': 2, 'feature': 'Install a specific application'}, {'category': 2, 'feature': 'Configure an installed application'}, {'category': 2, 'feature': 'Delete an installed application'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[1]/div[3]/div[1]
# [{'category': 1, 'feature': 'View details of available applications'}, {'category': 1, 'feature': 'Access external resources related to an application'}, {'category': 2, 'feature': 'Install a specific application'}, {'category': 2, 'feature': "Fork an application's code on GitHub"}]
# Marking final functionalities
# Final actions marked
# Visiting state eb63ed6dc62dbbe77e83ddfb963b455de6f6f5dc9d795a5c7d9002bd8ed91f97
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View system version information'}, {'category': 1, 'feature': 'Update system configuration settings'}, {'category': 2, 'feature': 'Create new configuration settings'}, {'category': 2, 'feature': 'Delete configuration settings'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[2]
# [{'category': 1, 'feature': 'Configure tax settings'}, {'category': 1, 'feature': 'View current tax settings'}, {'category': 2, 'feature': 'Create new tax rules or configurations'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[5]
# [{'category': 1, 'feature': 'View list of sales channels'}, {'category': 1, 'feature': 'Manage sales channels (create, edit, delete)'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[6]
# [{'category': 1, 'feature': 'Define content page types'}, {'category': 2, 'feature': 'Configure content pages'}, {'category': 2, 'feature': 'Configure other content settings'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Configure product attributes'}, {'category': 1, 'feature': 'Configure product types'}, {'category': 1, 'feature': 'View existing product attributes configuration'}, {'category': 1, 'feature': 'View existing product types configuration'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[3]/div[1]
# [{'category': 1, 'feature': 'View staff settings page'}, {'category': 2, 'feature': 'Manage staff members'}, {'category': 2, 'feature': 'Manage staff permission groups'}, {'category': 2, 'feature': 'Configure general staff settings'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[4]/div[1]
# [{'category': 1, 'feature': 'Configure shipping settings'}, {'category': 1, 'feature': 'View current shipping settings'}, {'category': 2, 'feature': 'Add a new shipping method'}, {'category': 2, 'feature': 'Delete an existing shipping method'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[4]/div[2]
# [{'category': 1, 'feature': 'Configure shipping methods'}, {'category': 1, 'feature': 'Configure warehouse information'}]
# Marking final functionalities
# Final actions marked
# Visiting state d6e18e9bf5e614af7cabb4e0a366dd7f1ccebc96be5af1ebe0e0d72368dfb817
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# [{'category': 1, 'feature': 'View list of products'}, {'category': 1, 'feature': 'View list of categories'}, {'category': 1, 'feature': 'View list of collections'}, {'category': 1, 'feature': 'View list of gift cards'}, {'category': 1, 'feature': 'View list of orders'}, {'category': 1, 'feature': 'View list of customers'}, {'category': 1, 'feature': 'View list of sales discounts'}, {'category': 1, 'feature': 'View list of pages (Content)'}, {'category': 1, 'feature': 'View list of translatable items'}, {'category': 1, 'feature': 'View list of installed apps'}, {'category': 1, 'feature': 'View system configuration settings'}, {'category': 2, 'feature': 'Create a new product'}, {'category': 2, 'feature': 'Create a new order'}, {'category': 2, 'feature': 'Create a new discount'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Create a new product category'}, {'category': 1, 'feature': 'View list of product categories'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'Search for product categories'}, {'category': 2, 'feature': 'View details of a specific category after search'}, {'category': 2, 'feature': 'Edit a specific category after search'}, {'category': 2, 'feature': 'Delete a specific category after search'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[3]
# [{'category': 1, 'feature': 'Configure number of items displayed per page'}, {'category': 1, 'feature': 'Navigate to the next page of items'}, {'category': 1, 'feature': 'Navigate to the previous page of items'}, {'category': 2, 'feature': 'Navigate to the first page of items'}, {'category': 2, 'feature': 'Navigate to the last page of items'}]
# Marking final functionalities
# Final actions marked
# Visiting state ff039e6a2058d8b58b31a686eb47771931379f306331ce797257011b59a1cd2f
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Create a new product collection'}, {'category': 1, 'feature': 'View the list of product collections'}, {'category': 2, 'feature': 'Update an existing collection'}, {'category': 2, 'feature': 'Delete an existing collection'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'Filter the list of collections'}, {'category': 1, 'feature': 'Search the list of collections'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]/div[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View list of product categories'}, {'category': 1, 'feature': 'View list of product collections'}, {'category': 1, 'feature': 'View list of gift cards'}]
# Marking final functionalities
# Final actions marked
# Visiting state 884423f31286201a69505181026c0d77d5e12271c3b842527dad8860e4cb2e27
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]
# [{'category': 1, 'feature': 'Create a new gift card product'}, {'category': 1, 'feature': 'Manage existing gift cards'}, {'category': 2, 'feature': 'View information about gift card products'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[3]
# [{'category': 1, 'feature': 'Filter the list of gift cards'}, {'category': 1, 'feature': 'Search the list of gift cards'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[6]
# [{'category': 1, 'feature': 'View orders containing gift cards'}, {'category': 1, 'feature': 'Understand why gift cards are not yet visible'}, {'category': 3, 'feature': 'Issue a new gift card'}, {'category': 3, 'feature': 'Edit an existing gift card'}, {'category': 3, 'feature': 'Delete an existing gift card'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View list of gift cards'}, {'category': 2, 'feature': 'Issue a new gift card'}, {'category': 2, 'feature': 'Filter the list of gift cards'}, {'category': 2, 'feature': 'Search the list of gift cards'}, {'category': 2, 'feature': 'View details of a specific gift card'}, {'category': 2, 'feature': 'Update details of a specific gift card'}, {'category': 2, 'feature': 'Delete a specific gift card'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[5]/div[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Configure rows per page display'}, {'category': 1, 'feature': 'View gift card list with configured rows per page'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[5]/div[1]/div[1]/div[2]
# [{'category': 1, 'feature': 'View the next page of gift cards'}, {'category': 1, 'feature': 'View the previous page of gift cards'}]
# Marking final functionalities
# Final actions marked
# Visiting state f4a8250b71addb4000c1c096f6022f7427de215d525259cd6286803bbbd95d5e
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[3]
# [{'category': 1, 'feature': 'View recent store activity'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[2]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[2]/div[2]
# Visiting state e848ec2cd5b4b14a62e36b0dd6c7fa98c114726cdc001ab78ce7a9b99879b4e3
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]/div[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[2]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[1]/div[1]/button[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]/div[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[1]/div[3]
# Visiting state 185270dfe22d1ec56d896dd8a734ea2ca27024196704b0c182386f7c7412b70a
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View Configuration settings'}, {'category': 1, 'feature': 'View Products'}, {'category': 1, 'feature': 'View Orders'}, {'category': 1, 'feature': 'View Customers'}, {'category': 1, 'feature': 'View Discounts'}, {'category': 1, 'feature': 'View Content pages'}, {'category': 1, 'feature': 'View Translations'}, {'category': 1, 'feature': 'View Apps'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]
# Visiting state 9e30d1f5c6f96004afe2dbe872507c56884e40be28e2ecb4224cabcace646fba
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# [{'category': 1, 'feature': 'View specific section of the dashboard'}, {'category': 2, 'feature': 'Update system configuration'}, {'category': 2, 'feature': 'Create a new entity'}, {'category': 2, 'feature': 'Update an existing entity'}, {'category': 2, 'feature': 'Delete an existing entity'}, {'category': 2, 'feature': 'Manage Apps'}, {'category': 2, 'feature': 'Manage Translations'}, {'category': 2, 'feature': 'Manage Content'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/a[1]
# [{'category': 3, 'feature': 'Return to previous page or state'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View list of attributes'}, {'category': 2, 'feature': 'Create a new attribute'}, {'category': 2, 'feature': 'Update an existing attribute'}, {'category': 2, 'feature': 'Delete an existing attribute'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]
# [{'category': 1, 'feature': 'Create a new attribute'}, {'category': 1, 'feature': 'View the list of attributes'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[1]/div[2]
# [{'category': 1, 'feature': 'View list of attributes'}, {'category': 2, 'feature': 'View details of a specific attribute'}, {'category': 2, 'feature': 'Edit a specific attribute'}, {'category': 2, 'feature': 'Delete a specific attribute'}, {'category': 3, 'feature': 'Create a new attribute'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[1]/div[3]
# [{'category': 1, 'feature': 'Edit attribute properties'}, {'category': 2, 'feature': 'View attribute details'}, {'category': 2, 'feature': 'Delete an attribute'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[3]/div[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Configure the number of rows displayed in a list or table'}, {'category': 2, 'feature': 'View a specific page of items after changing the number of rows per page'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[3]/div[1]/div[1]/div[2]
# [{'category': 1, 'feature': 'View next page of attribute list'}, {'category': 1, 'feature': 'View previous page of attribute list'}, {'category': 2, 'feature': 'View next page of draft order list'}, {'category': 2, 'feature': 'View previous page of draft order list'}]
# Marking final functionalities
# Final actions marked
# Visiting state 4c852b137ff1377dc23d3ee2d20f4b627d7d7f66f7357cf2c43cae6bc9740efc
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# [{'category': 1, 'feature': 'View list of products'}, {'category': 1, 'feature': 'View list of orders'}, {'category': 1, 'feature': 'View list of customers'}, {'category': 1, 'feature': 'View list of discounts'}, {'category': 1, 'feature': 'View list of pages (content)'}, {'category': 1, 'feature': 'View list of translations'}, {'category': 1, 'feature': 'View list of apps'}, {'category': 1, 'feature': 'Configure system settings'}, {'category': 2, 'feature': 'Create a new product'}, {'category': 2, 'feature': 'Create a new order'}, {'category': 2, 'feature': 'Create a new discount'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]
# [{'category': 1, 'feature': 'Create a new product type'}, {'category': 1, 'feature': 'View list of product types'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'View list of product types'}, {'category': 2, 'feature': 'Filter product types'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[2]
# [{'category': 1, 'feature': 'Search for product types'}, {'category': 1, 'feature': 'Filter product types'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[3]/table[1]/thead[1]
# [{'category': 1, 'feature': 'View list of product types'}, {'category': 1, 'feature': 'Sort list of product types by column'}, {'category': 1, 'feature': 'Select specific product types from list'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[3]/table[1]/tfoot[1]
# [{'category': 1, 'feature': 'View the next page of product types'}, {'category': 1, 'feature': 'View the previous page of product types'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]/div[3]/table[1]/tbody[1]
# [{'category': 1, 'feature': 'View specific product type details from list'}, {'category': 1, 'feature': 'Select specific product types from list'}, {'category': 2, 'feature': 'Edit specific product type details from list'}, {'category': 2, 'feature': 'Delete specific product types from list'}, {'category': 3, 'feature': 'Create a new product type'}]
# Marking final functionalities
# Final actions marked
# Visiting state 31f66473e1cff3e0b375285ad1a2af2f10652ad1cfea73b2ee532f33a2c4bbcb
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# [{'category': 1, 'feature': 'View various entities and configurations'}, {'category': 2, 'feature': 'Create various entities and configurations'}, {'category': 2, 'feature': 'Update various entities and configurations'}, {'category': 2, 'feature': 'Delete various entities and configurations'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View tax configuration settings'}, {'category': 2, 'feature': 'Update default tax settings'}, {'category': 2, 'feature': 'Manage country-specific tax exceptions'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]
# [{'category': 1, 'feature': 'Configure tax settings for channels'}, {'category': 1, 'feature': 'Configure tax settings for countries'}, {'category': 1, 'feature': 'Configure tax settings for tax classes'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[1]/section[1]/header[1]
# [{'category': 1, 'feature': 'Configure tax settings for a specific channel'}, {'category': 1, 'feature': 'Select a channel to configure tax settings'}, {'category': 1, 'feature': 'View default tax settings for a specific channel'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[1]/section[1]/li[1]
# [{'category': 1, 'feature': 'View default tax settings for the default channel'}, {'category': 1, 'feature': 'Configure default tax settings for the default channel'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[1]/section[1]/li[2]
# [{'category': 1, 'feature': 'Configure tax settings for a specific channel'}, {'category': 2, 'feature': 'View tax settings for a specific channel'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]/div[3]
# [{'category': 1, 'feature': 'Create a country-specific tax exception'}, {'category': 1, 'feature': 'View country-specific tax exceptions'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]/div[1]/div[2]
# [{'category': 1, 'feature': 'Configure whether to charge taxes for a channel'}, {'category': 1, 'feature': 'View current tax charging settings for a channel'}, {'category': 2, 'feature': 'Create a new tax configuration for a channel'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]/div[1]/div[3]
# [{'category': 1, 'feature': 'Configure price entry and display settings'}, {'category': 1, 'feature': 'View current price entry and display settings'}]
# Marking final functionalities
# Final actions marked
# Visiting state 111164af6151fdcfeccd467a4cb6cea0bfd8f4e1287aa93a3e69adbab1363870
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# ...
# [{'category': 1, 'feature': 'Configure user registration settings'}, {'category': 1, 'feature': 'View user registration settings'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Read current store checkout settings'}, {'category': 1, 'feature': 'Configure store checkout settings'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'Update store company information'}, {'category': 1, 'feature': 'Read store company information'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[2]/div[2]
# [{'category': 1, 'feature': 'Update store contact and address information'}, {'category': 1, 'feature': 'Read store contact and address information'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[4]
# [{'category': 1, 'feature': 'Configure checkout line limit'}, {'category': 1, 'feature': 'View current checkout line limit'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[2]/div[1]
# [{'category': 1, 'feature': 'Read store configuration settings'}, {'category': 1, 'feature': 'Update store configuration settings'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[2]/div[3]
# [{'category': 1, 'feature': 'Configure stock reservation time for authenticated users'}, {'category': 1, 'feature': 'View current store configuration settings'}, {'category': 2, 'feature': 'Configure stock reservation time for anonymous users'}, {'category': 2, 'feature': 'Configure checkout line limits'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[2]/div[5]
# [{'category': 1, 'feature': 'Configure stock reservation time for anonymous users'}, {'category': 1, 'feature': 'Clear stock reservation time for anonymous users'}]
# Marking final functionalities
# Final actions marked
# Visiting state 9c474f8b16f4294d8daa5eca9b9ad7f51085173eb1e41b58467c37c9e511c0d3
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'View the main list of plugins'}, {'category': 2, 'feature': 'Configure specific plugin settings'}, {'category': 2, 'feature': 'Update specific plugin settings'}, {'category': 2, 'feature': 'Delete a specific plugin'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[1]
# [{'category': 1, 'feature': 'Read information about Saleor App Store'}, {'category': 2, 'feature': 'Configure plugins'}, {'category': 2, 'feature': 'Delete a plugin'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[3]
# [{'category': 1, 'feature': 'Filter the list of plugins'}, {'category': 1, 'feature': 'Search the list of plugins'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[4]/table[1]/thead[1]
# [{'category': 1, 'feature': 'View list of plugins'}, {'category': 2, 'feature': 'Sort list of plugins by name'}, {'category': 2, 'feature': 'Sort list of plugins by configuration status'}, {'category': 2, 'feature': 'Sort list of plugins by channel status'}, {'category': 3, 'feature': 'Create a new plugin'}, {'category': 3, 'feature': 'Update the configuration of an existing plugin'}, {'category': 3, 'feature': 'Delete an existing plugin'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[4]/table[1]/tbody[1]
# [{'category': 1, 'feature': 'Edit specific plugin configuration'}, {'category': 2, 'feature': 'View details of specific plugin'}, {'category': 2, 'feature': 'Change activation status of specific plugin'}, {'category': 2, 'feature': 'Delete specific plugin'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]/div[4]/table[1]/tfoot[1]/tr[1]/td[1]/div[1]
# Visiting state 1bef47916cc38af7218b6f63968aff81eac3e5270fe58358eb1256c7fbd2c768
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# [{'category': 1, 'feature': 'View list of applications'}, {'category': 2, 'feature': 'Create a new application'}, {'category': 2, 'feature': 'Update an existing application'}, {'category': 2, 'feature': 'Delete an existing application'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# [{'category': 1, 'feature': 'Create a new custom application'}, {'category': 1, 'feature': 'View list of custom applications'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]
# [{'category': 1, 'feature': 'View list of custom applications'}, {'category': 2, 'feature': 'Create a new custom application'}]
# Marking final functionalities
# Final actions marked
# Visiting state 0a7bd3b0959273289643e2d56e0a4a8cb47e80b34d5998173423a457465eca84
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[5]/div[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/div[5]/div[1]/div[1]/div[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]/div[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]/div[1]/div[1]
# Visiting state 843960be6728f49a3affd12ded3fa057635ec66fe3030ae700bc9bc8957471d1
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]
# [{'category': 1, 'feature': 'Access configuration settings'}, {'category': 1, 'feature': 'Access home page'}, {'category': 1, 'feature': 'Access products management section'}, {'category': 1, 'feature': 'Access orders management section'}, {'category': 1, 'feature': 'Access customers management section'}, {'category': 1, 'feature': 'Access discounts management section'}, {'category': 1, 'feature': 'Access content management section'}, {'category': 1, 'feature': 'Access translations management section'}, {'category': 1, 'feature': 'Access apps management section'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]
# [{'category': 1, 'feature': 'View tax settings for Countries'}, {'category': 1, 'feature': 'View tax settings for Channels'}, {'category': 1, 'feature': 'View tax settings for Tax classes'}, {'category': 2, 'feature': 'Create a new tax rule for a Country'}, {'category': 2, 'feature': 'Update an existing tax rule for a Country'}, {'category': 2, 'feature': 'Delete an existing tax rule for a Country'}, {'category': 2, 'feature': 'Create a new tax rule for a Channel'}, {'category': 2, 'feature': 'Update an existing tax rule for a Channel'}, {'category': 2, 'feature': 'Delete an existing tax rule for a Channel'}, {'category': 2, 'feature': 'Create a new tax class'}, {'category': 2, 'feature': 'Update an existing tax class'}, {'category': 2, 'feature': 'Delete an existing tax class'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]
# [{'category': 1, 'feature': 'Add a country for tax purposes'}, {'category': 2, 'feature': 'View the list of countries for tax purposes'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[1]
# [{'category': 1, 'feature': 'Add a country for tax purposes'}, {'category': 1, 'feature': 'View the list of countries for tax purposes'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[2]
# [{'category': 1, 'feature': 'View list of countries for tax purposes'}, {'category': 1, 'feature': 'Add a country for tax purposes'}]
# Marking final functionalities
# Final actions marked
# Visiting state c1f5790deb1bf44941a91a49edd9d7376e5ecdc8194eb4de14e4aa4d8ae2d1a1
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/section[1]/li[1]/a[1]/div[1]/div[1]/button[1]
# [{'category': 1, 'feature': 'Delete a specific tax class'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[2]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/ul[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[3]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[4]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[5]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[1]/div[1]/aside[1]/div[2]/ol[1]/li[6]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[1]
# [{'category': 1, 'feature': 'View tax classes'}, {'category': 2, 'feature': 'View tax channels'}, {'category': 2, 'feature': 'View tax countries'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/div[1]
# [{'category': 1, 'feature': 'Create a new tax class'}, {'category': 1, 'feature': 'View list of tax classes'}, {'category': 2, 'feature': 'View details of a specific tax class'}, {'category': 2, 'feature': 'Delete an existing tax class'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/header[1]
# [{'category': 1, 'feature': 'Create a new tax class'}, {'category': 2, 'feature': 'Update an existing tax class'}, {'category': 2, 'feature': 'View details of an existing tax class'}, {'category': 3, 'feature': 'Delete an existing tax class'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[1]/section[1]
# [{'category': 1, 'feature': 'Delete an existing tax class'}, {'category': 2, 'feature': 'View details of a specific tax class'}, {'category': 3, 'feature': 'Create a new tax class'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]/div[1]
# [{'category': 1, 'feature': 'Update general information for a tax class'}, {'category': 1, 'feature': 'View general information for a tax class'}, {'category': 2, 'feature': 'Create a new tax class'}, {'category': 3, 'feature': 'Delete a specific tax class'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]/div[3]
# [{'category': 1, 'feature': 'View list of tax classes'}, {'category': 1, 'feature': 'View details of a specific tax class'}, {'category': 1, 'feature': 'Create a new tax class'}, {'category': 1, 'feature': 'Assign tax rates to a tax class'}, {'category': 2, 'feature': 'Delete a specific tax class'}]
# Marking final functionalities
# Final actions marked
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]/div[5]/div[1]
# Extracting component scenarios: //html[1]/body[1]/div[1]/main[1]/div[1]/div[2]/main[1]/form[1]/div[1]/div[2]/div[1]/div[3]/div[2]/div[5]/div[2]

# %%
features = in_memory_db.list_features()

print('\n'.join(map(
    lambda x: f'{x[0]}. {x[1][0]}',
    zip(
        range(1, len(features) + 1),
        sorted(
            list(map(lambda x: (x['text'], x['score']), features)),
            key=lambda x: x[1],
            reverse=True
        )
    )
)))
# Out:
# 1. Log into the application
# 2. Reset user password
# 3. View product or menu item details
# 4. View order details
# 5. View customer details
# 6. Access and view list of sales discounts and their details
# 7. View list of available content or page types
# 8. View list of installed applications
# 9. View overall dashboard information
# 10. View dashboard information filtered by channel
# 11. View recent store activity
# 12. Access and view list of products
# 13. View daily sales total
# 14. View the number of items currently out of stock
# 15. View list of sales orders
# 16. Search content list or products or discounts
# 17. View list of product types/categories
# 18. View list of gift cards and information about gift card products
# 19. Configure/View columns displayed in the product table/list in preferred format
# 20. Return to or navigate to the previous page or state
# 21. Select/Filter specific product types from a list
# 22. Filter the list of orders
# 23. View list of draft orders
# 24. Filter the list of discounts
# 25. Select or filter content or page types
# 26. View list of translations
# 27. Access external resources related to an application
# 28. View system version information
# 29. View tax settings for channels
# 30. View list of sales channels
# 31. Manage sales channels (create, edit, delete)
# 32. Create or define new content page types
# 33. View staff settings page
# 34. View current shipping settings
# 35. Edit/configure warehouse details after searching
# 36. View and search the list of product collections
# 37. Access and view list of orders
# 38. View list of translatable items
# 39. View and read current store configuration settings including contact, address, company information, and checkout settings with line limit.
# 40. Search for product types/categories
# 41. Configure the number of menu items or rows displayed per page in a list or table.
# 42. Create a new product collection
# 43. Filter the list of collections
# 44. Create or issue a new gift card or gift card product
# 45. Filter the list of gift cards
# 46. Search the list of gift cards
# 47. View orders containing gift cards
# 48. Understand why gift cards are not yet visible
# 49. View a specific page of items after changing the number of rows per page
# 50. View the next page of gift cards
# 51. View specific section of the dashboard
# 52. View list of attributes
# 53. View next page of attribute list
# 54. View previous page of attribute list
# 55. Access and view list of customers
# 56. Sort list of product types by column
# 57. View the next page of product types
# 58. View the previous page of product types
# 59. Configure tax settings for countries
# 60. Configure tax settings and assign tax rates to tax classes
# 61. View country-specific tax exceptions
# 62. Configure price entry and display settings
# 63. View list of staff members
# 64. Invite a new staff member
# 65. Search for staff members
# 66. Filter staff members list by status
# 67. View the list of permission groups
# 68. Search for shipping zones
# 69. View list of shipping zones
# 70. Delete a specific warehouse entry after searching
# 71. Search for warehouses
# 72. Sort list of shipping zones by name
# 73. View a specific subset of warehouses
# 74. View the next page of warehouses
# 75. View the previous page of warehouses
# 76. Create a new channel
# 77. Sort list of content types by name
# 78. Create a new navigation menu
# 79. View different pages of the menu list
# 80. Sort menu list by title
# 81. Delete a specific menu item
# 82. Select a specific menu item
# 83. View list of content pages
# 84. Configure user registration settings
# 85. View user registration settings
# 86. Configure store checkout settings including line limits
# 87. Configure stock reservation time for authenticated users
# 88. Clear stock reservation time for anonymous users
# 89. View list of plugins
# 90. Read information about Saleor App Store
# 91. Filter the list of plugins
# 92. Search the list of plugins
# 93. Create a new custom application
# 94. View list of custom applications
# 95. Access configuration settings
# 96. Access home page
# 97. Access content management section
# 98. Access translations management section
# 99. Access apps management section
# 100. View tax settings for countries
# 101. View list of tax classes settings
# 102. Add a country for tax purposes
# 103. View list of countries for tax purposes
# 104. Update store avatar image
# 105. Configure and create tax settings or a new tax rule for channels
# 106. Create a new voucher or discount
# 107. Install a specific application or app
# 108. Update or edit an existing order details or status
# 109. Update or edit existing customer details
# 110. Update or edit an existing discount
# 111. Delete or uninstall an existing or installed application
# 112. Delete an existing order, sales order, or draft order
# 113. Delete an existing voucher or discount
# 114. Be notified of new store activity
# 115. View sales total for a different time period
# 116. View a list of items that are out of stock
# 117. Update the stock levels of items
# 118. Search for a specific order
# 119. Apply a discount
# 120. View specific application details
# 121. Delete configuration settings
# 122. Create and manage product categories or types
# 123. Update/Edit/Manage details of a specific gift card
# 124. Duplicate a specific product
# 125. Configure order settings
# 126. Create a new order, draft order, or sales order
# 127. Edit an existing draft order
# 128. Delete translations for a specific language
# 129. Fork an application's code on GitHub
# 130. Manage/Update staff member information
# 131. Manage or create staff permission groups
# 132. Configure general staff settings
# 133. Delete an existing shipping method
# 134. View details of a specific page or product type/category
# 135. Edit a specific category after search
# 136. Delete a specific category after search
# 137. Navigate to the first page of items
# 138. Navigate to the last page of items
# 139. Update an existing collection
# 140. View details of a specific gift card
# 141. View details of a specific attribute
# 142. View next page of draft order list
# 143. View previous page of draft order list
# 144. Edit specific product type details from list
# 145. Manage and create country-specific tax exceptions
# 146. Delete a staff member
# 147. Create a new product
# 148. Update or edit an existing product
# 149. Edit an existing content page
# 150. Update or edit translation strings
# 151. Update store configuration settings including company information, contact, address
# 152. Delete an existing product
# 153. Delete an existing customer
# 154. Delete an existing content page
# 155. Create a new customer
# 156. Create a new content page
# 157. Create a new content section
# 158. Update an existing content section
# 159. Delete an existing content section
# 160. Configure an installed application
# 161. Create a new configuration setting
# 162. Export translations
# 163. Import translations
# 164. View details of a specific shipping zone after searching
# 165. Configure or update shipping zone settings
# 166. Delete a shipping zone
# 167. View specific warehouse details before editing
# 168. View details of a specific warehouse after searching
# 169. View details of a specific channel
# 170. Select multiple menus for bulk action
# 171. Sort menu list by number of items
# 172. Configure stock reservation time for anonymous users
# 173. Configure or edit specific plugin settings or configuration
# 174. Delete an existing plugin
# 175. Sort list of plugins by name
# 176. Sort list of plugins by configuration status
# 177. Sort list of plugins by channel status
# 178. View details of specific plugin
# 179. Change activation status of specific plugin
# 180. Update an existing application
# 181. Create a new tax rule for a Country
# 182. Update an existing tax rule for a Country
# 183. Delete an existing tax rule for a Country
# 184. Update an existing tax rule for a Channel
# 185. Delete an existing tax rule for a Channel
# 186. Create a new tax class
# 187. Update an existing tax class
# 188. Delete an existing tax class
# 189. View details of a tax class
# 190. Delete an existing channel
# 191. Delete an existing gift card
# 192. Create a new shipping zone
# 193. Create a new warehouse
# 194. Edit existing content or page types
# 195. Delete content types
# 196. Edit an existing menu
# 197. Delete an existing menu
# 198. Create a new plugin

# %%
save_db_to_file(in_memory_db, f'{APP_NAME}.db')
# Out:
# Database state saved successfully to DASHBOARD.db
